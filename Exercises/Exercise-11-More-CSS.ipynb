# %% [markdown]
# # Exercise 11
#
# Related Notes:
# - Web_7_HTML_And_CSS

# %% [markdown]
# ## Exercise 11.1
#
# <center>
#
# | First Name | Last Name | Age |
# |------------|-----------|-----|
# | Jill       | Smith     | 50  |
# | Eve        | Jackson   | 94  |
# | John       | Doe       | 80  |
#
# </center>
#
# Use the following HTML elements to create a HTML table as shown above:
#
# - `<table></table>`
# - `<tr></tr>`
# - `<th></th>`
# - `<td></td>`

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('tabletest.html')

if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [16/May/2023 21:21:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2023 21:21:33] "GET /static/tabletest.css HTTP/1.1" 304 -
# 127.0.0.1 - - [16/May/2023 21:21:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2023 21:21:43] "GET /static/tabletest.css HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2023 21:21:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2023 21:21:43] "GET /static/tabletest.css HTTP/1.1" 304 -
# 127.0.0.1 - - [16/May/2023 21:21:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2023 21:21:44] "GET /static/tabletest.css HTTP/1.1" 304 -
# 127.0.0.1 - - [16/May/2023 21:21:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2023 21:21:44] "GET /static/tabletest.css HTTP/1.1" 304 -
# 127.0.0.1 - - [16/May/2023 21:22:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2023 21:22:15] "GET /static/tabletest.css HTTP/1.1" 200 -

# %% [markdown]
# ## Exercise 11.2
#
# **Using an external stylesheet** (css) change the style of the following elements as follows:
#
# - `table` element:
#     - `font-family: Arial, sans-serif`
#     - `forder-collapse: collapse`
#     - `width: 75%`
#
# - `th` element:
#     - `border: 1px solid` and `color` with hexadecimal value of `dddddd`
#     - `padding: 8px`
#     - `text-align: center`
#
# - `td` element: same as `th` element
#
# Position the table at the centre as follows:
#
# <center>
# <img src="./img/exercise11-pic1.png"><br>
# </center>
#
# - Additional exercises at https://www.w3schools.com/css/exercise.asp?filename=exercise_table1

# %% [markdown]
# <p>Im the best??????</p>
# <img src="CSStableEx.png" alt="Fakenews">

# %% [markdown]
# ## Exercise 11.3
#
# Using the `table` element create a 2 rows by 2 columns layout for the 4 repeated paragraphs of following text in an html file.
#
# >Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam nibh felis, tempor lacinia elementum efficitur, feugiat a orci. Cras rhoncus hendrerit risus, congue luctus velit. Cras at mauris ante. Cras et justo ultricies, dignissim augue nec, varius velit. Ut auctor fermentum ornare. Aenean fermentum metus ex, quis dignissim purus luctus quis. Phasellus eget libero ultricies, ullamcorper nunc in, pretium mauris. In posuere sapien sit amet turpis pharetra, a laoreet nisl vehicula. Aenean at lacus in quam mollis malesuada et molestie nisi. Integer sed fermentum lectus.
#
# Your html document should look like the figure below:
#
# <center>
# <img src="./img/exercise11-pic3.png"><br>
# </center>

# %%
from flask import Flask, render_template

app = Flask(__name__)
funnytest = "Lorem ipsum dolor sit amet, consectetur adipiscing elit. \
    Nullam nibh felis, tempor lacinia elementum efficitur, feugiat a orci. \
        Cras rhoncus hendrerit risus, congue luctus velit. Cras at mauris ante.\
              Cras et justo ultricies, dignissim augue nec, varius velit.\
                  Ut auctor fermentum ornare.\
                      Aenean fermentum metus ex, quis dignissim purus luctus quis. \
                        Phasellus eget libero ultricies, ullamcorper nunc in, pretium mauris.\
                              In posuere sapien sit amet turpis pharetra, a laoreet nisl vehicula.\
                                  Aenean at lacus in quam mollis malesuada et molestie nisi.\
                                      Integer sed fermentum lectus."

@app.route('/')
def home():
    return render_template('tabletest2.html' , longtext = funnytest)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [16/May/2023 21:36:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2023 21:36:02] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ## Exercise 11.4
#
# Modify your `products.html` and `products.css` from Exercise 10 to use the table layout with 2 rows and 2 columns.
#
# - Add another product into your product catalogue.
# - Your product catalogue should look similar to this:
#
# <center>
# <img src="./img/exercise11-pic4.png"><br>
# </center>

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('productstable.html')

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/productsexercisetable.css HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/productsexercisetable.css HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [17/May/2023 16:57:53] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('new.html')

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/May/2023 17:18:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2023 17:18:46] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# ## Exercise 11.5
#
# 1. Download the file `practice4.html` from `resources` folder. Study the html and internal css in the html document.
# 2. Create a multi-column layout by encapsulating all the `item` elements within a container `div` element. Use a `class` attribute to identify the container element.
# 	- Set the value of the class attribute to `row`.
# 	- Set the display property of `row` element to `flex`.
#
# 	You should now have a multi-column display.
#
# 3.	By copying some of the existing contents from the `item` elements, create 4 more item elements as shown
#
# <center>
# <img src="./img/exercise11-pic5.png"><br>
# </center>
#
# Observe that the flexbox layout automatically adjusts the widths of the item elements but maintain the same height so that they all fill up the width of the parent container.
#
# 4.	To make all the item elements have the same width of 200px:
# 	-	Add the `flex` property to the `item` element and set its value to `200px`.
# 	>Do all the item elements have a width of 200px?<br>
# 	>NOTE:
# 	>The `flex: 200px` declaration set on the articles means that each will be at least 200px wide;
#
# 5.	In order to maintain the same 200px width for all the item elements, you have to allow the item elements to wrap-around and flow over to the next row.
# 	-	Add the `flex-wrap` property to the `row` element and set its value to `wrap`.
# 		This is how your layout should look like:
#
# <center>
# <img src="./img/exercise11-pic6.png"><br>
# </center>
#
#
# 	Observe that for the first row, all the item elements have the same width of around 200px and the second row, the remaining item elements fill out the width of the container.

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('practice4.html')

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/May/2023 23:05:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2023 23:05:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2023 23:05:36] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# ## Exercise 11.6
#
# Next, we shall create a navigation bar at the top of the page using the `flex` container concept.
#
# 1. Add the following lines of html code right after the body start tag as follows:
#     ```html
#     <body>
#         <ul>
#             <li>Home</li>
#             <li>New Item</li>
#             <li>Help</li>
#         </ul>
#     </body>
#     ```
# 2. Create the following styling for the `ul` element:
#     -	`margin:0`;
#     -	`list-style: none`;
#     -	`padding:0`;
#     -	`display:flex`;
#     -	`height:4em`;
#     -	`align-items: center`; This will align the child elements at the center of the vertical axis
#     -	`justify-content: flex-end`; This will align the child elements on the right of the horizontal axis
#
# 3. Create the following styling for the `li` element:
#     -	`margin: 1em 1em`;
#     -	`padding: 1em 1em`;
#     -	`font-family: Arial`;
#     -	`font-size: 1 em`;
#     -	`text-align: center`;
#     -	`border: grey solid`;
#     -	`border-radius : 1em`;
#
# The final layout and rendering of the html page should look similar to this:
#
# <center>
# <img src="./img/exercise11-pic7.png"><br>
# </center>

# %% [markdown]
# ## Exercise 11.7
#
# Modify your `products.html` and `products.css` to use the `flexbox` layout. Add a navigation bar at the top of the page.
# Your product catalogue should look similar to this:
#
# <center>
# <img src="./img/exercise11-pic8.png"><br>
# </center>

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('productsflexbox.html')

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [18/May/2023 08:37:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:37:57] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:37:58] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:37:58] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:37:58] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:37:58] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:08] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:09] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:13] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:13] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:13] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:13] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:13] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:14] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:14] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:14] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:14] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:14] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:38:57] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:51] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:39:51] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:51] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:51] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:39:51] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:51] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:39:52] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:41:52] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:52] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:52] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:52] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:41:52] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:41:53] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:01] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:01] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:01] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:01] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:01] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:02] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:02] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:02] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:02] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:02] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:12] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:28] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:42:40] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:43:49] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:49] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:43:49] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:49] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:49] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:43:50] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:06] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:06] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:06] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:06] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:06] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:07] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:09] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:15] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:16] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:20] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:20] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:20] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:20] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:20] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:21] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:28] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:28] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:28] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:28] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:28] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:29] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:34] "GET /static/productsexerciseflexbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2023 08:44:34] "GET /static/Junxiang.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:34] "GET /static/Chicken.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:34] "GET /static/Goofyemoji.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:44:34] "GET /static/Pencilworth.png HTTP/1.1" 304 -
# 127.0.0.1 - - [18/May/2023 08:45:57] "GET /static/productsexerciseflexbox.css HTTP/1.1" 304 -
